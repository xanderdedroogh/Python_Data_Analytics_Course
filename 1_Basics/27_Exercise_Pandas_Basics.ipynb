# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/lukebarousse/Python_Data_Analytics_Course/blob/main/1_Basics/27_Exercise_Pandas_Basics.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # Exercise - Pandas Basics

# %% [markdown]
# ## Topics Covered
#
# This exercise goes over:
#
# * Filtering by specific rows
# * Aggregate Functions
# * Group by
#
# ## Question
#
# Perform an exploratory analysis focusing on data jobs in each country. Look at the average yearly salary, job count, and salary range (minimum and maximum salaries).

# %% [markdown]
# ### Load Data
#
# First we'll load in the data.

# %%
# Install datasets Library (if not already installed)
# !pip install -U datasets

# Importing Libraries
import pandas as pd
from datasets import load_dataset

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.12/dist-packages (4.0.0)
# Collecting datasets
#   Downloading datasets-4.4.1-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets) (3.20.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from datasets) (2.0.2)
# Collecting pyarrow>=21.0.0 (from datasets)
#   Downloading pyarrow-22.0.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (3.2 kB)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets) (2.32.4)
# Requirement already satisfied: httpx<1.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.28.1)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.12/dist-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.19 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2025.10.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (2025.3.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.36.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from datasets) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from datasets) (6.0.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (3.13.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets) (4.11.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.16.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (1.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (2.5.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.22.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio->httpx<1.0.0->datasets) (1.3.1)
# Downloading datasets-4.4.1-py3-none-any.whl (511 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 511.6/511.6 kB 12.0 MB/s eta 0:00:00
# Downloading pyarrow-22.0.0-cp312-cp312-manylinux_2_28_x86_64.whl (47.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.7/47.7 MB 12.3 MB/s eta 0:00:00
# Installing collected packages: pyarrow, datasets
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 18.1.0
#     Uninstalling pyarrow-18.1.0:
#       Successfully uninstalled pyarrow-18.1.0
#   Attempting uninstall: datasets
#     Found existing installation: datasets 4.0.0
#     Uninstalling datasets-4.0.0:
#       Successfully uninstalled datasets-4.0.0
# Successfully installed datasets-4.4.1 pyarrow-22.0.0
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md: 0.00B [00:00, ?B/s]
# data_jobs.csv:   0%|          | 0.00/231M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/785741 [00:00<?, ? examples/s]

# %%
df['job_country'].isin(['Belgium']).any()
# Out:
# np.True_

# %% [markdown]
# ### Create New DataFrame
#
# Let's create a new DataFrame that filters the rows where the `job_country` is 'United States'. This is so we can only get data jobs in the US.

# %%
be_jobs = df[df['job_country'] == 'Belgium']
be_jobs = be_jobs[be_jobs['salary_year_avg'].notna()]
be_jobs
# Out:
#                   job_title_short  \
# 212                Data Scientist
# 25459   Machine Learning Engineer
# 26818                Data Analyst
# 38475                Data Analyst
# 54608                Data Analyst
# 54823               Data Engineer
# 115511              Data Engineer
# 115594              Data Engineer
# 128502       Senior Data Engineer
# 135705               Data Analyst
# 143488  Machine Learning Engineer
# 159624  Machine Learning Engineer
# 160577               Data Analyst
# 185616      Senior Data Scientist
# 189929           Business Analyst
# 204591  Machine Learning Engineer
# 209641              Data Engineer
# 227682           Business Analyst
# 234720  Machine Learning Engineer
# 263118             Data Scientist
# 265527               Data Analyst
# 273790               Data Analyst
# 286524  Machine Learning Engineer
# 301696              Data Engineer
# 302580               Data Analyst
# 319622          Software Engineer
# 321968               Data Analyst
# 331819               Data Analyst
# 333874               Data Analyst
# 385236              Data Engineer
# 407131              Data Engineer
# 426669               Data Analyst
# 451748             Data Scientist
# 464983               Data Analyst
# 473404               Data Analyst
# 476447      Senior Data Scientist
# 487751               Data Analyst
# 520770               Data Analyst
# 543579               Data Analyst
# 578735          Software Engineer
# 598627             Data Scientist
# 617916  Machine Learning Engineer
# 624303             Data Scientist
# 624807           Business Analyst
# 643591              Data Engineer
# 675521      Senior Data Scientist
# 683419              Data Engineer
# 702011             Data Scientist
# 709008           Business Analyst
# 734701               Data Analyst
# 736836              Data Engineer
# 745928           Business Analyst
# 752412             Data Scientist
# 761600               Data Analyst
# 767461              Data Engineer
# 770811               Data Analyst
# 772710             Data Scientist
#
#                                                 job_title  \
# 212          NATOIS-0008 Data Scientist (NS) - TUE 13 Jun
# 25459                        Expert in AI/ NLP/ ML - 4354
# 26818                               Business Data Analyst
# 38475                                      Data Architect
# 54608   C002854 IT Data Analyst - SME/Architect (NS) -...
# 54823                                       Data Engineer
# 115511                    Enterprise Architect (Big Data)
# 115594                      Azure Data Architect/Engineer
# 128502                  Senior Google Cloud Data Engineer
# 135705                                Master Data Analyst
# 143488                       Expert in AI/ NLP/ ML - 4399
# 159624        Machine Learning specialist - Legal systems
# 160577                                     Data Architect
# 185616                               Data Management Lead
# 189929   Power BI Specialist (Specific contract duration)
# 204591                                Expert in AI/NLP/ML
# 209641                                      Data Engineer
# 227682                Business Intelligence Expert - 4412
# 234720                                     MLOps Engineer
# 263118                                     Data Scientist
# 265527                                     Data Architect
# 273790         Data Product Analyst - Data & Analytics HR
# 286524                          Machine Learning Engineer
# 301696                                      Data Engineer
# 302580                                     Data Architect
# 319622                           Computer Vision Engineer
# 321968                                     Data Architect
# 331819                                 Azure Data Analyst
# 333874                          Data Management Assistant
# 385236                                   Sr Data Engineer
# 407131                                      Data Engineer
# 426669             C002927 Data Analyst (NS) - MON 17 Jul
# 451748                   Big Data Graduate Programme 2023
# 464983                                 Azure Data Analyst
# 473404  OCIO-0021 Expert on Information and Data Manag...
# 476447                  Senior Consultant in Data science
# 487751                               PMO - Data Reporting
# 520770  Clinical Trial Assistant (met focus op Data Ma...
# 543579  SC2023-002821 IKM - Data Management Coordinato...
# 578735                       BI Developer (SAP BO & Qlik)
# 598627                              Data Scientist - 4198
# 617916                            Machine Learning Expert
# 624303                                     Data Scientist
# 624807                                Power BI Specialist
# 643591                           Consultant Data Engineer
# 675521                  Senior Consultant in Data science
# 683419                               Medior Data Engineer
# 702011                                     Data Scientist
# 709008                       Business Intelligence Expert
# 734701  Master or PhD (Biomedical) Sciences - Clinical...
# 736836                               Medior Data Engineer
# 745928                       Business Intelligence Expert
# 752412                     Senior Associate, Data Science
# 761600              Data Management Assistant Coordinator
# 767461  SC2023-002740 Cyber Security Data Engineer - M...
# 770811  Clinical Trial Assistant (met focus op Data Ma...
# 772710                              Data Scientist - 4402
#
#                          job_location          job_via job_schedule_type  \
# 212                 Brussels, Belgium  via Ai-Jobs.net         Full-time
# 25459               Brussels, Belgium  via Ai-Jobs.net         Full-time
# 26818                         Belgium  via Ai-Jobs.net         Full-time
# 38475               Brussels, Belgium  via Ai-Jobs.net         Full-time
# 54608                   Mons, Belgium  via Ai-Jobs.net         Full-time
# 54823               Brussels, Belgium  via Ai-Jobs.net         Full-time
# 115511              Brussels, Belgium  via Ai-Jobs.net         Full-time
# 115594            Anderlecht, Belgium  via Ai-Jobs.net         Full-time
# 128502  Woluwe-Saint-Lambert, Belgium  via Ai-Jobs.net         Full-time
# 135705              Zaventem, Belgium  via Ai-Jobs.net         Full-time
# 143488              Brussels, Belgium  via Ai-Jobs.net         Full-time
# 159624              Brussels, Belgium  via Ai-Jobs.net         Full-time
# 160577              Machelen, Belgium  via Ai-Jobs.net         Full-time
# 185616              Brussels, Belgium  via Ai-Jobs.net         Full-time
# 189929              Brussels, Belgium  via Ai-Jobs.net         Full-time
# 204591              Brussels, Belgium  via Ai-Jobs.net         Full-time
# 209641              Machelen, Belgium  via Ai-Jobs.net         Full-time
# 227682              Brussels, Belgium  via Ai-Jobs.net         Full-time
# 234720                Leuven, Belgium  via Ai-Jobs.net         Full-time
# 263118              Brussels, Belgium  via Ai-Jobs.net         Full-time
# 265527              Zaventem, Belgium  via Ai-Jobs.net         Full-time
# 273790                        Belgium  via Ai-Jobs.net         Full-time
# 286524              Brussels, Belgium  via Ai-Jobs.net         Full-time
# 301696              Brussels, Belgium  via Ai-Jobs.net         Full-time
# 302580              Machelen, Belgium  via Ai-Jobs.net         Full-time
# 319622                Leuven, Belgium  via Ai-Jobs.net         Full-time
# 321968            Anderlecht, Belgium  via Ai-Jobs.net         Full-time
# 331819              Zaventem, Belgium  via Ai-Jobs.net         Full-time
# 333874              Mechelen, Belgium  via Ai-Jobs.net         Full-time
# 385236                       Anywhere         via Dice         Full-time
# 407131             Charleroi, Belgium  via Ai-Jobs.net         Full-time
# 426669       Braine-l'Alleud, Belgium  via Ai-Jobs.net         Full-time
# 451748              Brussels, Belgium  via Ai-Jobs.net         Full-time
# 464983              Machelen, Belgium  via Ai-Jobs.net         Full-time
# 473404              Brussels, Belgium  via Ai-Jobs.net         Full-time
# 476447              Brussels, Belgium  via Ai-Jobs.net         Full-time
# 487751              Brussels, Belgium  via Ai-Jobs.net         Full-time
# 520770              Mechelen, Belgium  via Ai-Jobs.net         Full-time
# 543579              Brussels, Belgium  via Ai-Jobs.net         Full-time
# 578735              Brussels, Belgium  via Ai-Jobs.net         Full-time
# 598627              Brussels, Belgium  via Ai-Jobs.net         Full-time
# 617916              Brussels, Belgium  via Ai-Jobs.net         Full-time
# 624303              Zaventem, Belgium  via Ai-Jobs.net         Full-time
# 624807              Brussels, Belgium  via Ai-Jobs.net         Full-time
# 643591              Brussels, Belgium  via Ai-Jobs.net         Full-time
# 675521               Antwerp, Belgium  via Ai-Jobs.net         Full-time
# 683419                        Belgium  via Ai-Jobs.net         Full-time
# 702011              Brussels, Belgium  via Ai-Jobs.net         Full-time
# 709008              Brussels, Belgium  via Ai-Jobs.net         Full-time
# 734701              Mechelen, Belgium  via Ai-Jobs.net         Full-time
# 736836              Mechelen, Belgium  via Ai-Jobs.net         Full-time
# 745928              Brussels, Belgium  via Ai-Jobs.net         Full-time
# 752412              Brussels, Belgium  via Ai-Jobs.net         Full-time
# 761600              Mechelen, Belgium  via Ai-Jobs.net         Full-time
# 767461                  Mons, Belgium  via Ai-Jobs.net         Full-time
# 770811              Mechelen, Belgium  via Ai-Jobs.net         Full-time
# 772710              Brussels, Belgium  via Ai-Jobs.net         Full-time
#
#         job_work_from_home search_location     job_posted_date  \
# 212                  False         Belgium 2023-06-05 13:56:28
# 25459                False         Belgium 2023-05-29 13:29:23
# 26818                False         Belgium 2023-11-08 13:54:53
# 38475                False         Belgium 2023-01-18 06:27:33
# 54608                False         Belgium 2023-05-16 06:46:09
# 54823                False         Belgium 2023-01-07 06:17:57
# 115511               False         Belgium 2023-03-14 08:41:46
# 115594               False         Belgium 2023-06-22 08:55:14
# 128502               False         Belgium 2023-02-08 16:42:01
# 135705               False         Belgium 2023-12-20 08:11:56
# 143488               False         Belgium 2023-07-05 08:41:17
# 159624               False         Belgium 2023-07-05 08:41:20
# 160577               False         Belgium 2023-08-03 15:29:20
# 185616               False         Belgium 2023-04-12 15:56:18
# 189929               False         Belgium 2023-04-27 15:33:38
# 204591               False         Belgium 2023-03-16 22:56:41
# 209641               False         Belgium 2023-07-26 22:11:56
# 227682               False         Belgium 2023-07-10 07:54:51
# 234720               False         Belgium 2023-02-28 07:15:21
# 263118               False         Belgium 2023-02-07 07:26:01
# 265527               False         Belgium 2023-07-12 07:50:13
# 273790               False         Belgium 2023-10-27 07:49:48
# 286524               False         Belgium 2023-05-31 18:03:34
# 301696               False         Belgium 2023-03-15 17:27:24
# 302580               False         Belgium 2023-07-26 17:12:05
# 319622               False         Belgium 2023-03-29 18:15:46
# 321968               False         Belgium 2023-06-22 17:55:14
# 331819               False         Belgium 2023-04-27 00:33:34
# 333874               False         Belgium 2023-01-05 23:42:39
# 385236                True         Belgium 2023-02-22 18:14:43
# 407131               False         Belgium 2023-01-14 16:23:57
# 426669               False         Belgium 2023-07-10 16:54:49
# 451748               False         Belgium 2023-01-18 14:27:23
# 464983               False         Belgium 2023-08-04 14:32:22
# 473404               False         Belgium 2023-04-18 14:53:55
# 476447               False         Belgium 2023-06-16 15:08:57
# 487751               False         Belgium 2023-07-26 11:12:05
# 520770               False         Belgium 2023-02-23 11:28:32
# 543579               False         Belgium 2023-04-27 19:33:30
# 578735               False         Belgium 2023-06-09 09:32:24
# 598627               False         Belgium 2023-03-10 09:17:05
# 617916               False         Belgium 2023-03-08 12:11:06
# 624303               False         Belgium 2023-07-21 12:56:36
# 624807               False         Belgium 2023-10-27 12:50:15
# 643591               False         Belgium 2023-08-23 12:18:09
# 675521               False         Belgium 2023-03-28 11:12:44
# 683419               False         Belgium 2023-12-22 10:12:09
# 702011               False         Belgium 2023-03-29 04:12:44
# 709008               False         Belgium 2023-05-18 03:01:31
# 734701               False         Belgium 2023-01-17 21:29:10
# 736836               False         Belgium 2023-03-01 21:20:17
# 745928               False         Belgium 2023-06-30 20:58:44
# 752412               False         Belgium 2023-04-05 20:30:07
# 761600               False         Belgium 2023-02-22 20:14:34
# 767461               False         Belgium 2023-03-07 01:56:46
# 770811               False         Belgium 2023-01-06 01:42:41
# 772710               False         Belgium 2023-07-07 01:34:55
#
#         job_no_degree_mention  job_health_insurance job_country salary_rate  \
# 212                     False                 False     Belgium        year
# 25459                   False                 False     Belgium        year
# 26818                   False                 False     Belgium        year
# 38475                   False                 False     Belgium        year
# 54608                   False                 False     Belgium        year
# 54823                   False                 False     Belgium        year
# 115511                  False                 False     Belgium        year
# 115594                  False                 False     Belgium        year
# 128502                   True                 False     Belgium        year
# 135705                   True                 False     Belgium        year
# 143488                  False                 False     Belgium        year
# 159624                  False                 False     Belgium        year
# 160577                  False                 False     Belgium        year
# 185616                  False                 False     Belgium        year
# 189929                  False                 False     Belgium        year
# 204591                  False                 False     Belgium        year
# 209641                   True                 False     Belgium        year
# 227682                  False                 False     Belgium        year
# 234720                  False                 False     Belgium        year
# 263118                  False                 False     Belgium        year
# 265527                  False                 False     Belgium        year
# 273790                   True                 False     Belgium        year
# 286524                  False                 False     Belgium        year
# 301696                  False                 False     Belgium        year
# 302580                  False                 False     Belgium        year
# 319622                  False                 False     Belgium        year
# 321968                  False                 False     Belgium        year
# 331819                  False                 False     Belgium        year
# 333874                  False                 False     Belgium        year
# 385236                  False                 False     Belgium        year
# 407131                  False                 False     Belgium        year
# 426669                  False                 False     Belgium        year
# 451748                  False                 False     Belgium        year
# 464983                   True                 False     Belgium        year
# 473404                  False                 False     Belgium        year
# 476447                  False                 False     Belgium        year
# 487751                  False                 False     Belgium        year
# 520770                  False                 False     Belgium        year
# 543579                  False                 False     Belgium        year
# 578735                  False                 False     Belgium        year
# 598627                  False                 False     Belgium        year
# 617916                  False                 False     Belgium        year
# 624303                  False                 False     Belgium        year
# 624807                  False                 False     Belgium        year
# 643591                  False                 False     Belgium        year
# 675521                  False                 False     Belgium        year
# 683419                  False                 False     Belgium        year
# 702011                  False                 False     Belgium        year
# 709008                  False                 False     Belgium        year
# 734701                  False                 False     Belgium        year
# 736836                  False                 False     Belgium        year
# 745928                  False                 False     Belgium        year
# 752412                  False                 False     Belgium        year
# 761600                  False                 False     Belgium        year
# 767461                  False                 False     Belgium        year
# 770811                  False                 False     Belgium        year
# 772710                  False                 False     Belgium        year
#
#         salary_year_avg  salary_hour_avg          company_name  \
# 212            157500.0              NaN             EMW, Inc.
# 25459           89100.0              NaN             CRI Group
# 26818           54988.0              NaN           Air Liquide
# 38475          165000.0              NaN          Blue Harvest
# 54608          111175.0              NaN             EMW, Inc.
# 54823           98301.5              NaN                 Talan
# 115511          72900.0              NaN     EUROPEAN DYNAMICS
# 115594          89100.0              NaN                  Ypto
# 128502          89100.0              NaN              Devoteam
# 135705          75067.5              NaN              DS Smith
# 143488          89100.0              NaN             CRI Group
# 159624          72900.0              NaN           Uni Systems
# 160577         165000.0              NaN              Devoteam
# 185616          89100.0              NaN                 Capco
# 189929          89100.0              NaN  Netcompany-Intrasoft
# 204591          72900.0              NaN     EUROPEAN DYNAMICS
# 209641          97444.0              NaN              Devoteam
# 227682          89100.0              NaN             CRI Group
# 234720          89100.0              NaN                 APIXA
# 263118          88128.0              NaN     EUROPEAN DYNAMICS
# 265527         165000.0              NaN              Devoteam
# 273790          56700.0              NaN                  Ypto
# 286524         101029.0              NaN           Uni Systems
# 301696         134241.0              NaN       Alter Solutions
# 302580         165000.0              NaN              Devoteam
# 319622          44418.5              NaN                 APIXA
# 321968         163782.0              NaN                  Ypto
# 331819         111175.0              NaN              Devoteam
# 333874          56700.0              NaN                   SGS
# 385236         120000.0              NaN       Teleperformance
# 407131         147500.0              NaN                 Talan
# 426669         111175.0              NaN             EMW, Inc.
# 451748          56700.0              NaN              Quantexa
# 464983          57500.0              NaN              Devoteam
# 473404          89100.0              NaN             EMW, Inc.
# 476447          56700.0              NaN          Sia Partners
# 487751          72900.0              NaN                  ARHS
# 520770          56700.0              NaN                   SGS
# 543579          80850.0              NaN             EMW, Inc.
# 578735          72900.0              NaN     EUROPEAN DYNAMICS
# 598627         157500.0              NaN             CRI Group
# 617916          72900.0              NaN           Uni Systems
# 624303         157500.0              NaN              Devoteam
# 624807          89100.0              NaN            Netcompany
# 643591          56700.0              NaN          Sia Partners
# 675521          89100.0              NaN          Sia Partners
# 683419         120000.0              NaN              HEINEKEN
# 702011          88128.0              NaN     EUROPEAN DYNAMICS
# 709008          72900.0              NaN           Uni Systems
# 734701          56700.0              NaN                   SGS
# 736836          98283.0              NaN                   SGS
# 745928          72900.0              NaN     EUROPEAN DYNAMICS
# 752412          89100.0              NaN      Dun & Bradstreet
# 761600          56700.0              NaN                   SGS
# 767461         147500.0              NaN             EMW, Inc.
# 770811          56700.0              NaN                   SGS
# 772710         157500.0              NaN             CRI Group
#
#                                                job_skills  \
# 212     ['c', 'r', 'sql', 'python', 'aws', 'azure', 'h...
# 25459   ['perl', 'python', 'matlab', 'r', 'bash', 'sql...
# 26818   ['express', 'power bi', 'excel', 'sheets', 'sap']
# 38475   ['sql', 'nosql', 'scala', 'java', 'c#', 'azure...
# 54608                                          ['sheets']
# 54823          ['sql', 'python', 'snowflake', 'redshift']
# 115511                                               None
# 115594  ['sql', 'c#', 'sql server', 'azure', 'databric...
# 128502  ['go', 'python', 'golang', 'java', 'spark', 'k...
# 135705                            ['powerpoint', 'excel']
# 143488                                               None
# 159624                                               None
# 160577  ['aws', 'azure', 'gcp', 'databricks', 'snowfla...
# 185616                                           ['gdpr']
# 189929                                               None
# 204591  ['perl', 'python', 'matlab', 'r', 'bash', 'sql...
# 209641  ['scala', 'python', 'aws', 'databricks', 'azur...
# 227682  ['sql', 'sql server', 'oracle', 'qlik', 'sap',...
# 234720  ['c++', 'python', 'azure', 'windows', 'linux',...
# 263118  ['r', 'python', 'perl', 'sas', 'sas', 'sql', '...
# 265527    ['sql', 'nosql', 'aws', 'azure', 'gcp', 'flow']
# 273790                                   ['azure', 'sap']
# 286524  ['perl', 'python', 'matlab', 'r', 'bash', 'sql...
# 301696     ['sas', 'sas', 'sql', 'sql server', 'alteryx']
# 302580    ['sql', 'nosql', 'aws', 'azure', 'gcp', 'flow']
# 319622                        ['c++', 'matlab', 'python']
# 321968                  ['nosql', 'azure', 'sap', 'flow']
# 331819  ['sql', 'python', 'go', 'sql server', 'aws', '...
# 333874                                             ['go']
# 385236  ['sql', 'azure', 'databricks', 'spark', 'power...
# 407131  ['t-sql', 'sql', 'sql server', 'azure', 'aws',...
# 426669  ['sql', 'c#', 'python', 'r', 'sql server', 'ss...
# 451748  ['scala', 'python', 'java', 'r', 'elasticsearc...
# 464983  ['sql', 'python', 'go', 'sql server', 'aws', '...
# 473404      ['sharepoint', 'excel', 'word', 'powerpoint']
# 476447                                               None
# 487751                                   ['sql', 'excel']
# 520770                                             ['go']
# 543579  ['gdpr', 'sharepoint', 'word', 'excel', 'power...
# 578735                             ['sql', 'sap', 'qlik']
# 598627  ['r', 'python', 'perl', 'sas', 'sas', 'sql', '...
# 617916  ['perl', 'python', 'matlab', 'r', 'sql', 'nosq...
# 624303  ['python', 'aws', 'pandas', 'numpy', 'pytorch'...
# 624807     ['sql', 'python', 'power bi', 'dax', 'gitlab']
# 643591  ['python', 'sql', 'nosql', 'postgresql', 'gcp'...
# 675521                                               None
# 683419                                          ['azure']
# 702011  ['python', 'r', 'perl', 'sas', 'sas', 'sql', '...
# 709008             ['sas', 'sas', 'sql', 'python', 'sap']
# 734701                                             ['go']
# 736836  ['go', 'sql', 'python', 'nosql', 'sql server',...
# 745928  ['sql', 'sql server', 'oracle', 'qlik', 'sap',...
# 752412                                               None
# 761600                                             ['go']
# 767461  ['python', 'php', 'sql', 'redhat', 'splunk', '...
# 770811                                             ['go']
# 772710  ['python', 'r', 'html', 'css', 'javascript', '...
#
#                                           job_type_skills
# 212     {'analyst_tools': ['tableau'], 'cloud': ['aws'...
# 25459   {'analyst_tools': ['sas'], 'cloud': ['aws', 'a...
# 26818   {'analyst_tools': ['power bi', 'excel', 'sheet...
# 38475   {'cloud': ['azure', 'bigquery'], 'libraries': ...
# 54608                       {'analyst_tools': ['sheets']}
# 54823   {'cloud': ['snowflake', 'redshift'], 'programm...
# 115511                                               None
# 115594  {'cloud': ['azure', 'databricks', 'aws'], 'dat...
# 128502  {'libraries': ['spark', 'kafka'], 'other': ['t...
# 135705         {'analyst_tools': ['powerpoint', 'excel']}
# 143488                                               None
# 159624                                               None
# 160577  {'cloud': ['aws', 'azure', 'gcp', 'databricks'...
# 185616                            {'libraries': ['gdpr']}
# 189929                                               None
# 204591  {'analyst_tools': ['sas'], 'cloud': ['aws', 'a...
# 209641  {'cloud': ['aws', 'databricks', 'azure'], 'lib...
# 227682  {'analyst_tools': ['qlik', 'sap'], 'async': ['...
# 234720  {'cloud': ['azure'], 'os': ['windows', 'linux'...
# 263118  {'analyst_tools': ['sas', 'tableau', 'sap'], '...
# 265527  {'cloud': ['aws', 'azure', 'gcp'], 'other': ['...
# 273790     {'analyst_tools': ['sap'], 'cloud': ['azure']}
# 286524  {'cloud': ['aws', 'azure'], 'databases': ['mon...
# 301696  {'analyst_tools': ['sas', 'alteryx'], 'databas...
# 302580  {'cloud': ['aws', 'azure', 'gcp'], 'other': ['...
# 319622       {'programming': ['c++', 'matlab', 'python']}
# 321968  {'analyst_tools': ['sap'], 'cloud': ['azure'],...
# 331819  {'analyst_tools': ['power bi', 'ssis'], 'cloud...
# 333874                            {'programming': ['go']}
# 385236  {'analyst_tools': ['power bi'], 'cloud': ['azu...
# 407131  {'cloud': ['azure', 'aws', 'gcp'], 'databases'...
# 426669  {'analyst_tools': ['ssrs', 'power bi', 'excel'...
# 451748  {'cloud': ['gcp'], 'databases': ['elasticsearc...
# 464983  {'analyst_tools': ['power bi', 'ssis'], 'cloud...
# 473404  {'analyst_tools': ['sharepoint', 'excel', 'wor...
# 476447                                               None
# 487751  {'analyst_tools': ['excel'], 'programming': ['...
# 520770                            {'programming': ['go']}
# 543579  {'analyst_tools': ['sharepoint', 'word', 'exce...
# 578735  {'analyst_tools': ['sap', 'qlik'], 'programmin...
# 598627  {'analyst_tools': ['sas', 'tableau', 'sap'], '...
# 617916  {'cloud': ['aws', 'azure'], 'databases': ['mon...
# 624303  {'cloud': ['aws'], 'libraries': ['pandas', 'nu...
# 624807  {'analyst_tools': ['power bi', 'dax'], 'other'...
# 643591  {'cloud': ['gcp', 'aws', 'azure'], 'databases'...
# 675521                                               None
# 683419                               {'cloud': ['azure']}
# 702011  {'analyst_tools': ['sas', 'tableau', 'sap'], '...
# 709008  {'analyst_tools': ['sas', 'sap'], 'programming...
# 734701                            {'programming': ['go']}
# 736836  {'analyst_tools': ['power bi', 'tableau'], 'as...
# 745928  {'analyst_tools': ['qlik', 'sap'], 'async': ['...
# 752412                                               None
# 761600                            {'programming': ['go']}
# 767461  {'analyst_tools': ['splunk'], 'os': ['redhat']...
# 770811                            {'programming': ['go']}
# 772710  {'cloud': ['azure', 'aws'], 'libraries': ['ten...

# %% [markdown]
# ### Average Yearly Salary
#
# Return the average yearly salary using `salary_year_avg` by the job title (`job_title_short`).

# %%
be_jobs.groupby('job_title_short')['salary_year_avg'].mean()
# Out:
# job_title_short
# Business Analyst              82620.000000
# Data Analyst                  96395.625000
# Data Engineer                107451.772727
# Data Scientist               119007.000000
# Machine Learning Engineer     83861.285714
# Senior Data Engineer          89100.000000
# Senior Data Scientist         78300.000000
# Software Engineer             58659.250000
# Name: salary_year_avg, dtype: float64

# %% [markdown]
# Instead of returning this in alphabetical order by country name. Let's order it by the highest to lowest using `sort_values()`.

# %%
be_jobs.groupby('job_title_short')['salary_year_avg'].mean().sort_values(ascending=False)
# Out:
# job_title_short
# Data Scientist               119007.000000
# Data Engineer                107451.772727
# Data Analyst                  96395.625000
# Senior Data Engineer          89100.000000
# Machine Learning Engineer     83861.285714
# Business Analyst              82620.000000
# Senior Data Scientist         78300.000000
# Software Engineer             58659.250000
# Name: salary_year_avg, dtype: float64

# %% [markdown]
# ### Job Count
#
# Count the total number of data analyst job postings for each job title to understand the job market size.
#
# We're using `size()` to get a straightforward count of all postings per job title (including those will nulls in other columns but not the country column).

# %%
be_jobs.groupby('job_title_short').size().sort_values(ascending=False)
# Out:
# job_title_short
# Data Analyst                 20
# Data Engineer                11
# Data Scientist                8
# Machine Learning Engineer     7
# Business Analyst              5
# Senior Data Scientist         3
# Software Engineer             2
# Senior Data Engineer          1
# dtype: int64

# %% [markdown]
# ### Salary Range
#
# Determine the minimum and maximum yearly salaries offered in each job title to assess the salary range and economic disparity.
#
# We use `agg()` because we want to get both the `min` and `max` `salary_year_avg` by `job_title_short`.

# %%
be_jobs.groupby('job_title_short')['salary_year_avg'].agg(['median', 'min', 'max', 'count']).sort_values(by='median', ascending=False)
# Out:
#                               median      min       max  count
# job_title_short
# Data Scientist             123300.00  56700.0  157500.0      8
# Data Engineer               98301.50  56700.0  147500.0     11
# Business Analyst            89100.00  72900.0   89100.0      5
# Machine Learning Engineer   89100.00  72900.0  101029.0      7
# Senior Data Scientist       89100.00  56700.0   89100.0      3
# Senior Data Engineer        89100.00  89100.0   89100.0      1
# Data Analyst                77958.75  54988.0  165000.0     20
# Software Engineer           58659.25  44418.5   72900.0      2
