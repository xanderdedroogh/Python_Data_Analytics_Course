# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/lukebarousse/Python_Data_Analytics_Course/blob/main/4_Problems/1_06_Operators Part 1.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# ## 🟩 Calculate Annual Salary (1.6.1)

# %%
# Code Needed
monthly_salary = 8000
print("Annual salary = $" + str(monthly_salary * 12))
# Out:
# Annual salary = $96000

# %% [markdown]
# ---

# %% [markdown]
# ## 🟩 Compare Salaries (1.6.2)

# %%
# Code Needed
avg_salary_analyst = 70000
avg_salary_scientist = 85000
if (avg_salary_analyst > avg_salary_scientist) == True:
  print("Is the average salary of a data analyst greater than that of a data scientist? Yes!")
else:
  print("Is the average salary of a data analyst greater than that of a data scientist? No!")
# Out:
# Is the average salary of a data analyst greater than that of a data scientist? No!

# %% [markdown]
# ---

# %% [markdown]
# ## 🟨 Calculate Remainder (1.6.3)

# %%
# Code Needed
total_applications = 123
job_openings = 67
jobs_not_filled = total_applications % job_openings
print(str(jobs_not_filled) + " jobs remaining")
# Out:
# 56 jobs remaining

# %% [markdown]
# ---

# %% [markdown]
# ## 🟨 Increment Job Postings (1.6.4)

# %%
# Code Needed
job_postings = 20
job_postings += 5
print(job_postings)
# Out:
# 25

# %% [markdown]
# ---

# %% [markdown]
# ## 🟨 Calculate Average Salary (1.6.5)

# %%
# Code Needed
min_salary = 50000
max_salary = 120000
average_salary = (min_salary + max_salary) / 2
print(average_salary)
# Out:
# 85000.0

# %% [markdown]
# ---
