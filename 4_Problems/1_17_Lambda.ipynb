# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/lukebarousse/Python_Data_Analytics_Course/blob/main/4_Problems/1_17_Lambda.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# ## 🟩 Calculate Average Salary (1.17.1)

# %%
# Code Needed
salaries = [95000, 120000, 105000, 90000, 130000]
(lambda salarie_list: sum(salarie_list) / len(salarie_list))(salaries)
# Out:
# 108000.0

# %% [markdown]
# ---

# %% [markdown]
# ## 🟨 Filter Job Titles (1.17.2)

# %%
# Code Needed
job_titles = ['Data Scientist', 'Data Engineer', 'Machine Learning Engineer', 'Data Analyst']
list(filter(lambda title: 'Data' in title, job_titles))
# Out:
# ['Data Scientist', 'Data Engineer', 'Data Analyst']

# %% [markdown]
# ---

# %% [markdown]
# ## 🟥 Filter Remote Python Jobs (1.17.3)

# %%
# Code Needed
job_postings = [
    {'title': 'Data Scientist', 'skills': ['Python', 'SQL'], 'remote': True},
    {'title': 'Data Analyst', 'skills': ['Excel', 'SQL'], 'remote': False},
    {'title': 'Machine Learning Engineer', 'skills': ['Python', 'TensorFlow'], 'remote': True},
    {'title': 'Software Developer', 'skills': ['Java', 'C++'], 'remote': True},
    {'title': 'Backend Engineer', 'skills': ['Python', 'Django'], 'remote': False},
    {'title': 'Business Intelligence Analyst', 'skills': ['Power BI', 'SQL'], 'remote': True},
    {'title': 'AI Researcher', 'skills': ['Python', 'PyTorch'], 'remote': True},
    {'title': 'Full Stack Developer', 'skills': ['JavaScript', 'React', 'Node.js'], 'remote': False},
    {'title': 'DevOps Engineer', 'skills': ['Python', 'Docker', 'Kubernetes'], 'remote': True},
    {'title': 'Cloud Architect', 'skills': ['AWS', 'Terraform'], 'remote': False},
    {'title': 'Data Engineer', 'skills': ['Python', 'Spark'], 'remote': True},
    {'title': 'Cybersecurity Analyst', 'skills': ['Linux', 'Networking'], 'remote': False},
    {'title': 'ML Ops Engineer', 'skills': ['Python', 'MLflow'], 'remote': True},
    {'title': 'Database Administrator', 'skills': ['SQL', 'PostgreSQL'], 'remote': False},
    {'title': 'QA Automation Engineer', 'skills': ['Python', 'Selenium'], 'remote': True},
]


list(filter(lambda jobs: 'Python' in jobs['skills'] and jobs['remote'], job_postings))
# Out:
# [{'title': 'Data Scientist', 'skills': ['Python', 'SQL'], 'remote': True},
#  {'title': 'Machine Learning Engineer',
#   'skills': ['Python', 'TensorFlow'],
#   'remote': True},
#  {'title': 'AI Researcher', 'skills': ['Python', 'PyTorch'], 'remote': True},
#  {'title': 'DevOps Engineer',
#   'skills': ['Python', 'Docker', 'Kubernetes'],
#   'remote': True},
#  {'title': 'Data Engineer', 'skills': ['Python', 'Spark'], 'remote': True},
#  {'title': 'ML Ops Engineer', 'skills': ['Python', 'MLflow'], 'remote': True},
#  {'title': 'QA Automation Engineer',
#   'skills': ['Python', 'Selenium'],
#   'remote': True}]

# %% [markdown]
# ---
